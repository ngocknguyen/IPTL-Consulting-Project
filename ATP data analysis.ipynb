# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("atp_players.csv")

# %%
df.head()
# Out:
#   player_id first_name first_initial  last_name    full_name  \
# 0      a002    Ricardo             R      Acuna      Acuna R
# 1      a001      Sadiq             S  Abdullahi  Abdullahi S
# 2      a005     Nelson             N      Aerts      Aerts N
# 3      a004       Egan             E      Adams      Adams E
# 4      a006     Ronald             R     Agenor     Agenor R
#
#                                           player_url flag_code  \
# 0  http://www.atpworldtour.com/en/players/ricardo...       CHI
# 1  http://www.atpworldtour.com/en/players/sadiq-a...       NGR
# 2  http://www.atpworldtour.com/en/players/nelson-...       BRA
# 3  http://www.atpworldtour.com/en/players/egan-ad...       USA
# 4  http://www.atpworldtour.com/en/players/ronald-...       USA
#
#                         residence                birthplace birthdate  ...  \
# 0                Jupiter, FL, USA           Santiago, Chile  19580113  ...
# ...

# %% [markdown]
# ## Data Exploratory Analysis on Players based on Countries

# %%
#plot to show countries with the most active, avid players from 2019 - 2020
plt.figure(figsize=(10,5), dpi=200)
ax = sns.countplot(x='flag_code', data = df,order= pd.value_counts(df['flag_code']).iloc[:20].index, palette='pastel')
plt.title('Top 20 countries with most male players from 2019-2021', weight='bold', fontsize=13)
plt.xlabel('Countries with Flag Codes',weight='bold', fontsize=11)
plt.ylabel('Count by Players',weight='bold', fontsize=11)

for i in ax.patches:
    ax.text (i.get_x() + i.get_width()/2,i.get_height()+ 20.,i.get_height(),
    horizontalalignment='center', fontsize = 8)

plt.savefig('atp_country.png')

# %%
atp = pd.read_excel("atp_2019_2021.xlsx")

# %%
atp.head()
# Out:
#    ATP  Location              Tournament       Date  Series    Court Surface  \
# 0    1  Brisbane  Brisbane International 2018-12-31  ATP250  Outdoor    Hard
# 1    1  Brisbane  Brisbane International 2018-12-31  ATP250  Outdoor    Hard
# 2    1  Brisbane  Brisbane International 2018-12-31  ATP250  Outdoor    Hard
# 3    1  Brisbane  Brisbane International 2018-12-31  ATP250  Outdoor    Hard
# 4    1  Brisbane  Brisbane International 2018-12-31  ATP250  Outdoor    Hard
#
#        Round  Best of         Winner  ... Lsets    Comment  B365W  B365L  \
# 0  1st Round        3    Dimitrov G.  ...   0.0  Completed   1.36   3.00
# 1  1st Round        3      Raonic M.  ...   0.0  Completed   1.18   4.50
# 2  1st Round        3  Kecmanovic M.  ...   0.0  Completed   1.57   2.25
# 3  1st Round        3     Millman J.  ...   1.0  Completed   1.40   2.75
# 4  1st Round        3    Uchiyama Y.  ...   0.0  Completed   2.62   1.44
#
#     PSW   PSL  MaxW  MaxL  AvgW  AvgL
# ...

# %%
atp.columns
# Out:
# Index(['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface',
#        'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts',
#        'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets',
#        'Lsets', 'Comment', 'B365W', 'B365L', 'PSW', 'PSL', 'MaxW', 'MaxL',
#        'AvgW', 'AvgL'],
#       dtype='object')

# %%
plt.figure(figsize=(12,4), dpi=200)
ax1= sns.countplot(x='Winner', data = atp ,order= pd.value_counts(atp['Winner']).iloc[:20].index,palette='pastel')
plt.title('Top 20 Winners in ATP from 2019-2021', weight='bold', fontsize=15)
plt.xticks(rotation = 30, ha = 'right')
plt.xlabel('Players', fontsize=12)
plt.ylabel('Count by Number of Winning', fontsize=12)

for i in ax1.patches:
    ax1.text (i.get_x() + i.get_width()/2,i.get_height()+ 1.,i.get_height(),
    horizontalalignment='center', fontsize = 9)
    
plt.savefig('atp_player.png')

# %%
plt.figure(figsize=(12,8), dpi=200)
ax2= sns.countplot(x='Best of', data = atp)
plt.title('Matches Distribution', weight='bold', fontsize=15)
plt.xlabel('Best of Matches', fontsize=12)
plt.ylabel('Count of Matches ', fontsize=12)

for i in ax2.patches:
    ax2.text (i.get_x() + i.get_width()/2,i.get_height()+ 20.,i.get_height(),
    horizontalalignment='center', fontsize = 12)

# %%
plt.figure(figsize=(12,6), dpi=200)
ax4 = sns.countplot(y='Surface', data =atp)
plt.title('Surface played by players',weight='bold',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Surface played by players')

# %% [markdown]
# ## Are there any upset in Grand Slams for Men players?

# %% [markdown]
# ### we consider upset if Loser Rank is less than 5 in ranking compared to Winner Rank

# %%
upset = atp[['Tournament','Series', 'Round', 'Winner','Loser','WRank', 'LRank']]

# %%
upset = upset[(upset.Series == 'Grand Slam')]

# %%
len(upset)
# Out:
# 1397

# %%
upset['upset'] = np.where(upset['WRank'] - upset['LRank'] >=5,1,0)

# %%
upset.head()
# Out:
#           Tournament      Series      Round           Winner          Loser  \
# 139  Australian Open  Grand Slam  1st Round      Anderson K.   Mannarino A.
# 140  Australian Open  Grand Slam  1st Round  Basilashvili N.     Eubanks C.
# 141  Australian Open  Grand Slam  1st Round         Albot R.        Mmoh M.
# 142  Australian Open  Grand Slam  1st Round     Travaglia S.   Andreozzi G.
# 143  Australian Open  Grand Slam  1st Round      Verdasco F.  Kecmanovic M.
#
#      WRank  LRank  upset
# 139    6.0   42.0      0
# 140   20.0  170.0      0
# 141   98.0  107.0      0
# 142  137.0   77.0      1
# 143   28.0  125.0      0

# %%
plt.figure(figsize=(12,6), dpi=200)
ax7= sns.countplot(x='upset',hue='Tournament', data = upset)
plt.title('Upset in Grand Slams from 2019-2021', weight='bold', fontsize=15)
plt.xlabel('Upset', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

for i in ax7.patches:
    ax7.text (i.get_x() + i.get_width()/2,i.get_height()+ 1.,i.get_height(),
    horizontalalignment='center', fontsize = 12)

# %%
australian_open_upset = (round(95/(286+95),2)*100)
australian_open_upset
# Out:
# 25.0

# %%
french_open_upset = (round(105/(276+105),2)*100)
french_open_upset
# Out:
# 28.000000000000004

# %%
wimbledon_upset = (round(68/(186+68),2)*100)
wimbledon_upset
# Out:
# 27.0

# %%
us_open_upset = (round(126/(255+126),2)*100)
us_open_upset
# Out:
# 33.0

# %%
slams_upset = pd.DataFrame({'Tournament': ['Australian Open', 'French Open', 'Wimbledon', 'US Open'],
                   'Percentage of Upset': [australian_open_upset, french_open_upset, wimbledon_upset, us_open_upset]})

# %%
slams_upset
# Out:
#         Tournament  Percentage of Upset
# 0  Australian Open                 25.0
# 1      French Open                 28.0
# 2        Wimbledon                 27.0
# 3          US Open                 33.0
